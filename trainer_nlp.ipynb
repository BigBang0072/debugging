# %%
from temp_analysis import *

# %%
expt_name = "10.amzn"
num_domains = 8

analyze_amazon_experiments(expt_name,num_domains)
# Out:
#                 0         1
# 0  responsiveness  0.016641
# 1         stipple  0.016789
# 2       himalayan  0.017009
# 3         decline  0.019614
# 4          glugun  0.022047
#              0         1
# 0        olden  0.016635
# 1  thermaliner  0.017203
# 2        https  0.017446
# 3         rpgs  0.018628
# 4      darkish  0.018768
#                 0         1
# 0           ennui  0.012493
# 1     provocation  0.013005
# 2  czechoslovakia  0.015701
# 3       operamini  0.019781
# 4    horrifically  0.024622
#                0         1
# 0    waakzamheid  0.021496
# 1      rorschach  0.021578
# 2       screamin  0.022747
# 3        abrided  0.023672
# 4  unresponsible  0.025197
#                   0         1
# 0             stink  0.014416
# 1  autobiographical  0.016995
# 2             lontg  0.019640
# 3              12ee  0.020434
# 4       discression  0.022006
#              0         1
# 0         ichy  0.013211
# 1  handgrenade  0.014612
# 2  assaination  0.017382
# ...
