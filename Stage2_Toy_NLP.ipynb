# %%
import numpy as np
import json
from pprint import pprint
import matplotlib.pyplot as plt
from collections import defaultdict

plt.rcParams['figure.figsize'] = [16, 8]

# %%
#Opening the experiment json
def load_probe_metric_list(fname):
    with open(fname,"r") as rhandle:
        probe_metric_list = json.load(rhandle)
    
    #Converting the metric into usable format
    pdict = defaultdict(list)
    for idx in range(len(probe_metric_list)):
        pdict["angle:m-t0"].append(probe_metric_list[idx]["conv_angle_dict"]["main"]["topic0"])
        pdict["angle:m-t1"].append(probe_metric_list[idx]["conv_angle_dict"]["main"]["topic1"])
        pdict["angle:t0-t1"].append(probe_metric_list[idx]["conv_angle_dict"]["topic0"]["topic1"])
        pdict["acc:main"].append(probe_metric_list[idx]["classifier_acc_dict"]["main"])
        pdict["acc:topic0"].append(probe_metric_list[idx]["classifier_acc_dict"]["topic0"])
        pdict["acc:topic1"].append(probe_metric_list[idx]["classifier_acc_dict"]["topic1"])
    return pdict

# %%
#Plotting the results
def plot_the_metrics(pdict):
    #fig,ax = plt.subplots(2,1,gridspec_kw={'width_ratios': [3, 1]})
    fig,ax = plt.subplots(2,1)
    ax[0].plot(pdict["angle:m-t0"],"-o",label="angle:m-t0")
    ax[0].plot(pdict["angle:m-t1"],"-o",label="angle:m-t1")
    ax[0].plot(pdict["angle:t0-t1"],"-o",label="angle:t0-t1")
    
    ax[1].plot(pdict["acc:main"],"-o",label="acc:main")
    ax[1].plot(pdict["acc:topic0"],"-o",label="acc:topic0")
    ax[1].plot(pdict["acc:topic1"],"-o",label="acc:topic1")
    
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_ylim(0.0,1.0)
    ax[0].set_xlabel("null space removal iteration")
    ax[0].set_ylabel("relative conv angle (multiple of pi)")
    
    ax[1].legend()
    ax[1].grid(True)
    ax[1].set_ylim(0.0,1.0)
    ax[1].set_xlabel("null space removal iteration")
    ax[1].set_ylabel("Accuracy")
    
    
    plt.show()


def plot_the_metric_grid(pdict_lol,p0_vals,p1_vals,plot):
    '''
    [
        p0: [pdict of this row: varying p1],
        p0: [pdict of this row: varying p1],
        ...
        
        Here we will just plot the validation accuracy
    ]
    '''
    fig,ax = plt.subplots(len(pdict_lol),len(pdict_lol[0]))
    for ridx,pdict_p1 in enumerate(pdict_lol):
        for cidx,pdict in enumerate(pdict_p1):
            if(plot=="acc"):
                ax[ridx,cidx].plot(pdict["acc:main"],"-o",label="acc:main")
                ax[ridx,cidx].plot(pdict["acc:topic0"],"-o",label="acc:topic0")
                ax[ridx,cidx].plot(pdict["acc:topic1"],"-o",label="acc:topic1")
            else:
                ax[ridx,cidx].plot(pdict["angle:m-t0"],"-o",label="angle:m-t0")
                ax[ridx,cidx].plot(pdict["angle:m-t1"],"-o",label="angle:m-t1")
                ax[ridx,cidx].plot(pdict["angle:t0-t1"],"-o",label="angle:t0-t1")
            
            ax[ridx,cidx].legend()
            ax[ridx,cidx].grid(True)
            ax[ridx,cidx].set_ylim(0.0,1.0)
            ax[ridx,cidx].set_xlabel("null space removal iteration")
            ax[ridx,cidx].set_ylabel("Accuracy")
            ax[ridx,cidx].set_title("p0={:0.2f} & p1={:0.2f}".format(p0_vals[ridx],p1_vals[cidx]))
    
    plt.plot()

# %%
#p=0.5, main_topic=0

fname0 = "nlp_logs/ct14.inlp.0/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
#Pre projection step
fname0 = "nlp_logs/ct15.inlp.0/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
#p=0.5, main_topic=1

fname0 = "nlp_logs/ct14.inlp.1/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
fname0 = "nlp_logs/ct15.inlp.1/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
#p=0.9, main_topic=0

fname0 = "nlp_logs/ct14.inlp.2/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
fname0 = "nlp_logs/ct15.inlp.2/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
#p=0.9, main_topic=1

fname0 = "nlp_logs/ct14.inlp.3/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
fname0 = "nlp_logs/ct15.inlp.3/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
fname0 = "nlp_logs/ct15.inlp.0/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
fname0 = "nlp_logs/ct15.inlp.1/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
fname0 = "nlp_logs/ct15.inlp.2/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
fname0 = "nlp_logs/ct15.inlp.3/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %% [markdown]
# # #FP Steps vs p-value

# %%
# p0=0.5 , p1=1.0
fname0 = "nlp_logs/ct16.inlp.0/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
# p0=0.6 , p1=1.0
fname0 = "nlp_logs/ct16.inlp.1/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
# p0=0.7 , p1=1.0
fname0 = "nlp_logs/ct16.inlp.2/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
# p0=0.8 , p1=1.0
fname0 = "nlp_logs/ct16.inlp.3/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
# p0=0.9 , p1=1.0
fname0 = "nlp_logs/ct16.inlp.5/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
# p0=0.99 , p1=1.0
fname0 = "nlp_logs/ct16.inlp.4/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %% [markdown]
# # #TP Steps vs p-value

# %%
# p0=1.0 , p1=0.5
fname0 = "nlp_logs/ct17.inlp.0/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
# p0=1.0 , p1=0.6
fname0 = "nlp_logs/ct17.inlp.1/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
# p0=1.0 , p1=0.7
fname0 = "nlp_logs/ct17.inlp.2/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
# p0=1.0 , p1=0.8
fname0 = "nlp_logs/ct17.inlp.3/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
# p0=1.0 , p1=0.9
fname0 = "nlp_logs/ct17.inlp.5/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %%
# p0=1.0 , p1=0.99
fname0 = "nlp_logs/ct17.inlp.4/probe_metric_list.json"
pdict0 = load_probe_metric_list(fname0)
plot_the_metrics(pdict0)

# %% [markdown]
# # main,topic0 and topic1 convergence grid

# %%
pdict_lol = [
    [
        load_probe_metric_list("nlp_logs/ct19.inlp.0/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.1/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.2/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.3/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.4/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.5/probe_metric_list.json"),
    ],
    [
        load_probe_metric_list("nlp_logs/ct19.inlp.6/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.7/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.8/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.9/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.10/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.11/probe_metric_list.json"),
    ],
    [
        load_probe_metric_list("nlp_logs/ct19.inlp.12/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.13/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.14/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.15/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.16/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.17/probe_metric_list.json"),
    ],
    [
        load_probe_metric_list("nlp_logs/ct19.inlp.18/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.19/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.20/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.21/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.22/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.23/probe_metric_list.json"),
    ],
    [
        load_probe_metric_list("nlp_logs/ct19.inlp.24/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.25/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.26/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.27/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.28/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.29/probe_metric_list.json"),
    ],
    [
        load_probe_metric_list("nlp_logs/ct19.inlp.30/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.31/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.32/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.33/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.34/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct19.inlp.35/probe_metric_list.json"),
    ],
]

# %%
plt.rcParams['figure.figsize'] = [60, 40]
plot_the_metric_grid(pdict_lol,[0.5,0.6,0.7,0.8,0.9,1.0],[0.5,0.6,0.7,0.8,0.9,1.0],plot="acc")

# %%
plt.rcParams['figure.figsize'] = [60,40]
plot_the_metric_grid(pdict_lol,[0.5,0.6,0.7,0.8,0.9,1.0],[0.5,0.6,0.7,0.8,0.9,1.0],plot="angle")

# %% [markdown]
# # 2 topic convergence with noise

# %%
pdict_lol = [
    [
        load_probe_metric_list("nlp_logs/ct20.inlp.0/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.1/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct20.inlp.2/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.3/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct20.inlp.4/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.5/probe_metric_list.json"),
    ],
#     [
#         load_probe_metric_list("nlp_logs/ct19.inlp.6/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.7/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.8/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.9/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.10/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.11/probe_metric_list.json"),
#     ],
    [
        load_probe_metric_list("nlp_logs/ct20.inlp.12/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.13/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct20.inlp.14/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.15/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct20.inlp.16/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.17/probe_metric_list.json"),
    ],
#     [
#         load_probe_metric_list("nlp_logs/ct19.inlp.18/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.19/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.20/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.21/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.22/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.23/probe_metric_list.json"),
#     ],
    [
        load_probe_metric_list("nlp_logs/ct20.inlp.24/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.25/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct20.inlp.26/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.27/probe_metric_list.json"),
        load_probe_metric_list("nlp_logs/ct20.inlp.28/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct19.inlp.29/probe_metric_list.json"),
    ],
#     [
#         load_probe_metric_list("nlp_logs/ct17.inlp.0/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct17.inlp.2/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct17.inlp.5/probe_metric_list.json"),
#         load_probe_metric_list("nlp_logs/ct17.inlp.4/probe_metric_list.json"),
#     ],
]

# %%
plt.rcParams['figure.figsize'] = [30,20]
plot_the_metric_grid(pdict_lol,[0.5,0.7,0.9],[0.5,0.7,0.9],plot="acc")

# %%
plt.rcParams['figure.figsize'] = [30,20]
plot_the_metric_grid(pdict_lol,[0.5,0.7,0.9],[0.5,0.7,0.9],plot="angle")
