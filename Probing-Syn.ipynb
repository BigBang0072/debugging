# %%
import numpy as np
import json
from pprint import pprint
import matplotlib.pyplot as plt
from collections import defaultdict

plt.rcParams['figure.figsize'] = [16, 68]
from plot_utils import *

# %% [markdown]
# # Timeline

# %%
run_list=[1,]
pval_list=[0.5,0.6,0.7,0.8,0.9,0.99]
plot_item_list = [
                    "angle:m-t1",
                    "acc:main",
                    "acc:topic1",
                    "topic1_smin",
                    "main_smin_topic1",
                    "topic1_main",
                    "topic1_pdelta_m1t1",
                    "topic1_pdelta_m1t0",
                    "topic1_pdelta_m0t1",
                    "topic1_pdelta_m0t0",
                    "topic1_pdelta_smin",
                    "topic1_pdelta_all",
                    "topic1_logpdelta",
]


ax=None


#Other hyperparam
model_type="nbow"
dataset="nlp_toy2"
neg1_fmethod="remove_negation"
lt="x_entropy"
drate=0.0
l2=0.0
hretrain="no_warm_encoder"
d="causal_removed_sp" #"causal_removed_sp","causal_rebalance_sp","causal_same_sp"
n=0.0
h=0
remmode="probing"
advepoch=10
mainepoch=10
s=1000


all_result_dict = get_all_result_timeline(run_list=run_list,
                                      pval_list=pval_list,
                                      fname_pattern="dataset/{}/nlp_logs/pt.rel.mt({}).neg1_fmethod({}).remmode({}).mainmode({}).advepoch({}).lt({}).drate({}).l2({}).n({}).h({}).s({}).p({}).r({})/probe_metric_list.json".format(
                                                                              dataset,
                                                                              model_type,
                                                                              neg1_fmethod,
                                                                              remmode,
                                                                              d,
                                                                              advepoch,
                                                                              lt,
                                                                              drate,
                                                                              l2,
                                                                              n,
                                                                              h,
                                                                              s,
                                                                              "{}",
                                                                              "{}",
                                      )
)
plot_one_timeline(pval_list,all_result_dict,plot_item_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-de15c1f8fc45> in <module>
#      38
#      39
# ---> 40 all_result_dict = get_all_result_timeline(run_list=run_list,
#      41                                       pval_list=pval_list,
#      42                                       fname_pattern="dataset/{}/nlp_logs/pt.rel.mt({}).neg1_fmethod({}).remmode({}).mainmode({}).advepoch({}).lt({}).drate({}).l2({}).n({}).h({}).s({}).p({}).r({})/probe_metric_list.json".format(
#
# ~\Downloads\debugging\plot_utils.py in get_all_result_timeline(run_list, pval_list, fname_pattern, clean_smin_acc_list_dict)
#     180             fname = fname_pattern.format(pval,ridx)
#     181             # print("Loading file: {}".format(fname))
# --> 182             prdict = load_probe_metric_list(fname)
#     183             prdict_list.append(prdict)
#     184         #Getting the aggregate list
#
# ~\Downloads\debugging\plot_utils.py in load_probe_metric_list(fname, only_one, epoch)
#      36 #Opening the experiment json
#      37 def load_probe_metric_list(fname,only_one=False,epoch=None):
# ---> 38     with open(fname,"r") as rhandle:
#      39         probe_metric_list = json.load(rhandle)
#      40
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/nlp_toy2/nlp_logs/pt.rel.mt(nbow).neg1_fmethod(remove_negation).remmode(probing).mainmode(causal_removed_sp).advepoch(10).lt(x_entropy).drate(0.0).l2(0.0).n(0.0).h(0).s(1000).p(0.5).r(1)/probe_metric_list.json'

# %% [markdown]
# # Variation with Samples

# %%
run_list=[1,2,3]
pval_list=[0.5,0.6,0.7,0.8,0.9,0.99]
plot_item_list = [
                    "angle:m-t1",
                    "acc:main",
                    "acc:topic1",
                    "topic1_smin",
                    "main_smin_topic1",
                    "topic1_main",
                    "topic1_pdelta_m1t1",
                    "topic1_pdelta_m1t0",
                    "topic1_pdelta_m0t1",
                    "topic1_pdelta_m0t0",
                    "topic1_pdelta_smin",
                    "topic1_pdelta_all",
                    "topic1_logpdelta",
]


ax=None


#Other hyperparam
model_type="nbow"
dataset="nlp_toy2"
neg1_fmethod="remove_negation"
lt="x_entropy"
drate=0.0
l2=0.0
hretrain="no_warm_encoder"
d="causal_same_sp" #"causal_removed_sp","causal_rebalance_sp","causal_same_sp"
n=0.0
h=0
remmode="probing"
advepoch=10
mainepoch=10
s=1000

for s in [1000,]:
    all_result_dict = get_all_result_dict(run_list=run_list,
                                          pval_list=pval_list,
                                          enum=advepoch+mainepoch,
                                          fname_pattern="dataset/{}/nlp_logs/pt.rel.mt({}).neg1_fmethod({}).remmode({}).mainmode({}).advepoch({}).lt({}).drate({}).l2({}).n({}).h({}).s({}).e({}).p({}).r({})/probe_metric_list.json".format(
                                                                              dataset,
                                                                              model_type,
                                                                              neg1_fmethod,
                                                                              remmode,
                                                                              d,
                                                                              advepoch,
                                                                              lt,
                                                                              drate,
                                                                              l2,
                                                                              n,
                                                                              h,
                                                                              s,
                                                                              mainepoch,
                                                                              "{}",
                                                                              "{}",
                                      )
    )
    ax = plot_all_results(ax,pval_list,all_result_dict,plot_item_list,extra_label=", prob-sample={}".format(s))


plt.show()

# %% [markdown]
# # Variation with Parameters

# %%
run_list=[0,]
pval_list=[0.5,0.6,0.7,0.8,0.9,0.99]
plot_item_list = [
                    "angle:m-t0",
                    "acc:main",
                    "acc:topic0",
                    "topic0_smin",
                    "topic0_main",
                    "topic0_pdelta",
                    "topic0_logpdelta"
]


ax=None

#Other hyperparam
model_type="bert-base-uncased"
lt="x_entropy"
drate=0.0
l2=0.0
hretrain="no_warm_encoder"
d="non_causal"
n=0.0
h=0
remmode="adversarial"
adv_rm_method="adv_rm_with_main"
grstrength=1.0
advepoch=5
s=10000

for model_type in ["bert-base-uncased","bert-large-uncased"]:
    all_result_dict = get_all_result_dict(run_list=run_list,
                                          pval_list=pval_list,
                                          enum=advepoch,
                                          fname_pattern="nlp_logs/pt.rel.model_type({}).remmode({}).adv_rm_method({}).grstrength({}).advepoch({}).lt({}).dropout_rate({}).l2({}).hretrain({}).noise({}).hlayer({}).sample({}).p({}).run({})/probe_metric_list.json".format(
                                                                                  model_type,
                                                                                  remmode,
                                                                                  adv_rm_method,
                                                                                  grstrength,
                                                                                  advepoch,
                                                                                  lt,
                                                                                  drate,
                                                                                  l2,
                                                                                  hretrain,
                                                                                  n,
                                                                                  h,
                                                                                  s,
                                                                                  "{}",
                                                                                  "{}",
                                          )
    )
    ax = plot_all_results(ax,pval_list,all_result_dict,plot_item_list,extra_label=", method={}".format(model_type))


plt.show()


'''
As the correlation is increasing the number of samples of minoroty group is also decreasing.
So, is the average minority group accuracy estimate good enough?
'''
# Out:
# '\nAs the correlation is increasing the number of samples of minoroty group is also decreasing.\nSo, is the average minority group accuracy estimate good enough?\n'

# %% [markdown]
# # Variation with noise

# %%
run_list=[0,]
pval_list=[0.5,0.6,0.7,0.8,0.9,0.99]
plot_item_list = [
                    "angle:m-t0",
                    "acc:main",
                    "acc:topic0",
                    "topic0_smin",
                    "topic0_main",
                    "topic0_pdelta",
                    "topic0_logpdelta"
]


ax=None

#Other hyperparam
model_type="bert-base-uncased"
lt="x_entropy"
drate=0.0
l2=0.0
hretrain="no_warm_encoder"
d="non_causal"
n=0.0
h=0
remmode="adversarial"
adv_rm_method="adv_rm_with_main"
grstrength=1.0
advepoch=5
s=10000

for n in [0.0,0.025,0.05,0.1]:
    all_result_dict = get_all_result_dict(run_list=run_list,
                                          pval_list=pval_list,
                                          enum=advepoch,
                                          fname_pattern="nlp_logs/pt.rel.model_type({}).remmode({}).adv_rm_method({}).grstrength({}).advepoch({}).lt({}).dropout_rate({}).l2({}).hretrain({}).noise({}).hlayer({}).sample({}).p({}).run({})/probe_metric_list.json".format(
                                                                                  model_type,
                                                                                  remmode,
                                                                                  adv_rm_method,
                                                                                  grstrength,
                                                                                  advepoch,
                                                                                  lt,
                                                                                  drate,
                                                                                  l2,
                                                                                  hretrain,
                                                                                  n,
                                                                                  h,
                                                                                  s,
                                                                                  "{}",
                                                                                  "{}",
                                          )
    )
    ax = plot_all_results(ax,pval_list,all_result_dict,plot_item_list,extra_label=", noise={}".format(n))


plt.show()


'''
As the correlation is increasing the number of samples of minoroty group is also decreasing.
So, is the average minority group accuracy estimate good enough?
'''
# Out:
# '\nAs the correlation is increasing the number of samples of minoroty group is also decreasing.\nSo, is the average minority group accuracy estimate good enough?\n'

# %% [markdown]
# # Variation with epochs

# %%
run_list=[0,]
pval_list=[0.5,0.6,0.7,0.8,0.9,0.99]
plot_item_list = [
                    "angle:m-t0",
                    "acc:main",
                    "acc:topic0",
                    "topic0_smin",
                    "topic0_main",
                    "topic0_pdelta",
                    "topic0_logpdelta"
]


ax=None

#Other hyperparam
model_type="bert-base-uncased"
lt="x_entropy"
drate=0.0
l2=0.0
hretrain="no_warm_encoder"
d="non_causal"
n=0.0
h=0
remmode="adversarial"
adv_rm_method="adv_rm_with_main"
grstrength=1.0
advepoch=5
s=10000

for advepoch_num in [1,2,3,4,5]:
    all_result_dict = get_all_result_dict(run_list=run_list,
                                          pval_list=pval_list,
                                          enum=advepoch_num,
                                          fname_pattern="nlp_logs/pt.rel.model_type({}).remmode({}).adv_rm_method({}).grstrength({}).advepoch({}).lt({}).dropout_rate({}).l2({}).hretrain({}).noise({}).hlayer({}).sample({}).p({}).run({})/probe_metric_list.json".format(
                                                                                  model_type,
                                                                                  remmode,
                                                                                  adv_rm_method,
                                                                                  grstrength,
                                                                                  advepoch,
                                                                                  lt,
                                                                                  drate,
                                                                                  l2,
                                                                                  hretrain,
                                                                                  n,
                                                                                  h,
                                                                                  s,
                                                                                  "{}",
                                                                                  "{}",
                                          )
    )
    ax = plot_all_results(ax,pval_list,all_result_dict,plot_item_list,extra_label=", epoch={}".format(advepoch_num))


plt.show()


'''
As the correlation is increasing the number of samples of minoroty group is also decreasing.
So, is the average minority group accuracy estimate good enough?
'''
# Out:
# '\nAs the correlation is increasing the number of samples of minoroty group is also decreasing.\nSo, is the average minority group accuracy estimate good enough?\n'

# %% [markdown]
# # Variation with GR-Strength

# %%
run_list=[1,2,3]
pval_list=[0.5,0.6,0.7,0.8,0.9,0.99]
plot_item_list = [
                    "angle:m-t0",
                    "acc:main",
                    "acc:topic0",
                    "topic0_smin",
                    "topic0_main",
                    "topic0_pdelta_m1t0",
                    "topic0_pdelta_m0t0",
                    "topic0_pdelta_smin",
                    "topic0_pdelta_all",
                    "topic0_logpdelta"
]


ax=None
#Plotting the convergence result first to see the conparison
model_type="roberta-base"
lt="x_entropy"
drate=0.0
l2=0.0
hretrain="no_warm_encoder"
d="non_causal"
n=0.0
h=0
e=20
s=10000
neg1_flip_method="remove_negation"
all_result_dict = get_all_result_dict(run_list=run_list,
                                      pval_list=pval_list,
                                      enum=e,
                                      fname_pattern="dataset/multinli_1.0/nlp_logs/pt.rel.model_type({}).neg1_fmethod({}).lt({}).dropout_rate({}).l2({}).noise({}).hlayer({}).sample({}).epoch({}).pval({}).rnum({})/probe_metric_list.json".format(
                                                                              model_type,
                                                                              neg1_flip_method,
                                                                              lt,
                                                                              drate,
                                                                              l2,
                                                                              n,
                                                                              h,
                                                                              s,
                                                                              e,
                                                                              "{}",
                                                                              "{}",
                                      )
)
ax = plot_all_results(ax,pval_list,all_result_dict,plot_item_list,extra_label=", conv-sample={}".format(s))




#Other hyperparam
# model_type="roberta-base"
lt="x_entropy"
drate=0.0
l2=0.0
hretrain="no_warm_encoder"
d="non_causal"
n=0.0
h=0
remmode="adversarial"
adv_rm_method="adv_rm_with_main"
grstrength=1.0
advepoch=20
advepoch_num=advepoch
s=1000

#"0.01","0.1","0.3","0.5","0.7","0.9","1.0","2.0","4.0","8.0"

for grstrength in [0.0,0.0001,0.001,0.01,0.1,0.5,1.0,10.0]:
    all_result_dict = get_all_result_dict(run_list=run_list,
                                          pval_list=pval_list,
                                          enum=advepoch_num,
                                          fname_pattern="dataset/multinli_1.0/nlp_logs/pt.rel.mt({}).neg1_fmethod({}).remmode({}).adv_rm_method({}).grstrength({}).advepoch({}).lt({}).drate({}).l2({}).n({}).h({}).s({}).p({}).r({})/probe_metric_list.json".format(
                                                                              model_type,
                                                                              neg1_fmethod,
                                                                              remmode,
                                                                              adv_rm_method,
                                                                              grstrength,
                                                                              advepoch,
                                                                              lt,
                                                                              drate,
                                                                              l2,
                                                                              n,
                                                                              h,
                                                                              s,
                                                                              "{}",
                                                                              "{}",
                                      )
    )
    ax = plot_all_results(ax,pval_list,all_result_dict,plot_item_list,extra_label=", adv-GR={}".format(grstrength))


plt.show()


'''
As the correlation is increasing the number of samples of minoroty group is also decreasing.
So, is the average minority group accuracy estimate good enough?
'''
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-e5eb60fbbaaf> in <module>
#      69
#      70 for grstrength in [0.0,0.0001,0.001,0.01,0.1,0.5,1.0,10.0]:
# ---> 71     all_result_dict = get_all_result_dict(run_list=run_list,
#      72                                           pval_list=pval_list,
#      73                                           enum=advepoch_num,
#
# ~\Downloads\debugging\plot_utils.py in get_all_result_dict(run_list, pval_list, enum, fname_pattern)
#     113         for nidx in run_list:
#     114             fname = fname_pattern.format(pval,nidx)
# --> 115             prdict = load_probe_metric_list(fname,only_one=True,epoch=enum-1)
#     116             prdict_list.append(prdict)
#     117         #Getting the aggregate result
#
# ~\Downloads\debugging\plot_utils.py in load_probe_metric_list(fname, only_one, epoch)
#       8 #Opening the experiment json
#       9 def load_probe_metric_list(fname,only_one=False,epoch=None):
# ---> 10     with open(fname,"r") as rhandle:
#      11         probe_metric_list = json.load(rhandle)
#      12
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/multinli_1.0/nlp_logs/pt.rel.mt(roberta-base).neg1_fmethod(remove_negation).remmode(adversarial).adv_rm_method(adv_rm_with_main).grstrength(0.0).advepoch(20).lt(x_entropy).drate(0.0).l2(0.0).n(0.0).h(0).s(10000).p(0.5).r(1)/probe_metric_list.json'
